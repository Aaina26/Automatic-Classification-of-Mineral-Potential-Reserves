# %%
import filecmp
import os

# %%
path='/content/drive/MyDrive/Data1(no black patches)/Manganese'

# %%
for img in os.listdir(path):  # iterate over each image per dogs and cats
        if img != '1 (1).tiff':
          if filecmp.cmp(os.path.join(path,'1 (1).tiff'),os.path.join(path,img)):
            os.remove(os.path.join(path,img))
